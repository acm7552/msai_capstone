# %%
import pandas as pd
import numpy as np
import os

# %%
aria     = pd.read_csv("/home/stu14/s16/acm7552/Capstone/results/AEROBLADE_outputs/aria_detection_results.csv")
artbench = pd.read_csv("/home/stu14/s16/acm7552/Capstone/results/AEROBLADE_outputs/artbench_detection_results.csv")

# %%
aria
# Out:
#      Unnamed: 0                                           fake_dir transform  \
# 0             0  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 1            16  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 2            32  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 3            48  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 4            64  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# ..          ...                                                ...       ...
# 187         123  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 188         139  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 189         155  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 190         171  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
# 191         187  /home/stu14/s16/acm7552/Capstone/data/ARIA_dat...     clean
#
# ...

# %%
artbench
# Out:
#      Unnamed: 0                                           fake_dir transform  \
# 0             0  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 1            20  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 2            40  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 3            60  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 4            80  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# ..          ...                                                ...       ...
# 235         157  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 236         177  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 237         197  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 238         217  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
# 239         237  /home/stu14/s16/acm7552/Capstone/data/Real_AI_...     clean
#
# ...

# %%
print(aria["acc"].mean())
print(aria["ap"].mean())
print(aria["auc"].mean())
print()



print(artbench["acc"].mean())
print(artbench["ap"].mean())
print(artbench["auc"].mean())
# Out:
# 0.4864501953125
# 0.4036658316964961
# 0.3116620381673177
#
# 0.48138020833333334
# 0.40635157586966814
# 0.30966517130533855
